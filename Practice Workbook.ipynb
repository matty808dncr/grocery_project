# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"GROCERY SS (1).xlsx", sheet_name=[0,1])
df.keys()
df.values()
# Out:
# dict_values([                       Item Category   Price  Quantity       Date
# 0                  loverboy   drinks   12.99       2.0 2021-03-21
# 1     Birthday Cake Cookies   snacks    3.50       2.0 2021-03-21
# 2      magic animal cookies   snacks    3.50       2.0 2021-03-21
# 3    frosted animal cookies   snacks    3.99       1.0 2021-03-21
# 4                green peas   snacks    2.99       1.0 2021-03-21
# ..                      ...      ...     ...       ...        ...
# 270           green peppers  produce    1.87       1.0 2021-03-29
# 271                   limes  produce    1.99       1.0 2021-03-29
# 272                jalapeno  produce    0.28       1.0 2021-03-29
# 273                  garlic  produce    0.52       1.0 2021-03-29
# 274                   total    total  106.94       1.0 2021-03-29
#
# [275 rows x 5 columns],                   Item    Category  Price  Quantity       Date
# 0               coffee  dry pantry   3.99       1.0 2021-04-11
# ...

# %%
march = pd.read_excel(r"GROCERY SS (1).xlsx", 'March 21')
april = pd.read_excel(r"GROCERY SS (1).xlsx", 'April 21')
march.head()
# Out:
#                      Item Category  Price  Quantity       Date
# 0                loverboy   drinks  12.99       2.0 2021-03-21
# 1   Birthday Cake Cookies   snacks   3.50       2.0 2021-03-21
# 2    magic animal cookies   snacks   3.50       2.0 2021-03-21
# 3  frosted animal cookies   snacks   3.99       1.0 2021-03-21
# 4              green peas   snacks   2.99       1.0 2021-03-21

# %%
april.head()
# Out:
#               Item    Category  Price  Quantity       Date
# 0           coffee  dry pantry   3.99       1.0 2021-04-11
# 1  montauk seltzer      drinks  20.99       1.0 2021-04-11
# 2         loverboy      drinks  25.98       1.0 2021-04-11
# 3            bread  dry pantry   5.50       1.0 2021-04-11
# 4  animal crackers      snacks   3.99       1.0 2021-04-11

# %%
m_d = march.groupby('Date')
m_d.describe()
# Out:
#            Price                                                              \
#            count       mean        std   min     25%    50%      75%     max
# Date
# 2021-03-01   5.0   8.074000   7.189665  1.99  5.2900  5.590   6.9900   20.51
# 2021-03-04  20.0   7.173500  15.351979  0.99  2.1225  3.840   4.9900   71.67
# 2021-03-06  17.0   9.169412  18.504537  0.20  1.8800  3.490   8.2400   79.46
# 2021-03-07  36.0  11.642222  34.448030  0.14  2.6400  3.985   7.9825  206.99
# 2021-03-10  19.0   6.421053  13.513737  0.27  1.5150  2.590   4.8600   60.90
# 2021-03-14  27.0  10.180741  25.781569  0.34  2.4950  4.690   7.7000  137.93
# 2021-03-17  27.0   7.383704  18.604247  0.64  1.9900  3.000   5.5900   99.43
# 2021-03-21  32.0   8.938437  26.749233  0.40  1.9400  3.015   6.0900  154.12
# 2021-03-25  10.0  12.304000  18.019480  1.95  5.1150  6.265  10.4900   62.62
# 2021-03-27  35.0   7.856571  20.484816  0.44  1.9950  3.880   4.9900  123.53
# ...

# %%
a_d = april.groupby('Date')
a_d.describe()
# Out:
#            Price                                                             \
#            count       mean        std   min     25%    50%     75%     max
# Date
# 2021-04-01   7.0  12.108571  13.765090  3.19  4.6200  6.860  11.545   42.38
# 2021-04-03  14.0   9.956429  16.759488  1.68  2.9900  3.495   6.490   64.34
# 2021-04-06  10.0   6.179000   8.937747  1.37  2.1775  3.310   4.365   31.01
# 2021-04-11  31.0  11.541613  31.891218  0.28  2.9900  3.990   6.640  180.68
# 2021-04-19  38.0   8.143947  24.750416  0.72  2.2650  3.990   5.250  155.88
# 2021-04-22   8.0  12.622500  17.017288  0.67  3.9600  7.015  11.090   51.72
# 2021-04-25  53.0   9.405849  33.978084  0.17  1.9900  3.690   7.290  250.33
# 2021-04-28   8.0  10.635000  13.623708  0.60  3.5675  6.990  10.880   42.79
# 2021-04-30  10.0   8.706000  12.610944  0.80  3.4900  5.190   5.865   43.90
#
#            Quantity
#               count      mean       std  min  25%  50%  75%  max
# Date
# ...

# %%
march.columns
# Out:
# Index(['Item', 'Category', 'Price', 'Quantity', 'Date'], dtype='object')

# %%
march.sort_values(by='Item').head(5)
# Out:
#                       Item Category  Price  Quantity       Date
# 251                    ???      NaN   1.59       1.0 2021-03-29
# 1    Birthday Cake Cookies   snacks   3.50       2.0 2021-03-21
# 138        alouette cheese    dairy   6.99       1.0 2021-03-01
# 144        alouette cheese    dairy   4.99       1.0 2021-03-04
# 39   aloutte cheese spread    dairy   6.99       1.0 2021-03-17

# %%
mcat = march.groupby(['Category'])
mcat.describe()
# Out:
#              Price                                                          \
#              count       mean        std    min      25%     50%       75%
# Category
# canned goods  11.0   1.621818   0.712486   0.89   1.0400   1.490    2.1400
# cereal         1.0   3.990000        NaN   3.99   3.9900   3.990    3.9900
# charcuterie    7.0   8.427143   2.314028   5.93   6.3900   8.310    9.9900
# dairy         22.0   4.163182   1.702943   1.49   2.6900   4.240    4.9900
# drinks         9.0   8.213333   4.602325   1.99   3.9900   6.990   12.9900
# dry pantry    33.0   4.819697   3.398892   0.34   2.1900   3.990    6.3900
# fish           1.0   7.410000        NaN   7.41   7.4100   7.410    7.4100
# frozen         1.0   2.490000        NaN   2.49   2.4900   2.490    2.4900
# meat           7.0   8.550000   4.042512   3.88   5.7900   7.050   11.4000
# meat          21.0   8.052857   3.798009   1.79   5.4900   7.990   10.6300
# ...

# %%
items = march.groupby(['Item']).sum()
order = items.sort_values(by="Quantity", ascending=False).head(15)
order[1:11]
# Out:
#                 Price  Quantity
# Item
# skirt steak     35.67       4.0
# limes            5.65       4.0
# garlic           2.72       4.0
# chicken thighs  34.38       4.0
# lemons          13.46       4.0
# salami          30.70       4.0
# loverboy        38.97       4.0
# chicken broth    9.47       3.0
# broccoli         5.54       3.0
# cilantro         2.97       3.0

# %%
date = df.groupby('Date')
date

# %%
date.describe()
# Out:
#            Price                                                              \
#            count       mean        std   min     25%    50%      75%     max
# Date
# 2021-03-01   5.0   8.074000   7.189665  1.99  5.2900  5.590   6.9900   20.51
# 2021-03-04  20.0   7.173500  15.351979  0.99  2.1225  3.840   4.9900   71.67
# 2021-03-06  17.0   9.169412  18.504537  0.20  1.8800  3.490   8.2400   79.46
# 2021-03-07  36.0  11.642222  34.448030  0.14  2.6400  3.985   7.9825  206.99
# 2021-03-10  19.0   6.421053  13.513737  0.27  1.5150  2.590   4.8600   60.90
# 2021-03-14  27.0  10.180741  25.781569  0.34  2.4950  4.690   7.7000  137.93
# 2021-03-17  26.0   3.843462   2.833238  0.64  1.9900  2.995   5.5650   13.21
# 2021-03-21  32.0   8.938437  26.749233  0.40  1.9400  3.015   6.0900  154.12
# 2021-03-25  10.0  12.304000  18.019480  1.95  5.1150  6.265  10.4900   62.62
# 2021-03-27  34.0   4.454412   3.866951  0.44  1.9925  3.735   4.5650   17.28
# ...

# %%
salami = items[items=='salami']
salami
# Out:
# 26     salami
# 76     salami
# 219    salami
# 248    salami
# Name: Item, dtype: object

# %%
salami.count()
# Out:
# 4

# %%
march.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Item      264 non-null    object
#  1   Category  263 non-null    object
#  2   Price     264 non-null    float64
#  3   Quantity  263 non-null    float64
#  4   Date      263 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 10.9+ KB

# %%
april.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Item      179 non-null    object
#  1   Category  179 non-null    object
#  2   Price     179 non-null    float64
#  3   Quantity  177 non-null    float64
#  4   Date      179 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 7.4+ KB

# %%
april.describe()
# Out:
#             Price    Quantity
# count  179.000000  177.000000
# mean     9.635922    1.011299
# std     26.386096    0.105996
# min      0.170000    1.000000
# 25%      2.440000    1.000000
# 50%      3.990000    1.000000
# 75%      6.990000    1.000000
# max    250.330000    2.000000

# %%
marchtotal = march[items=='total']
marchtotal.sort_values('Date')
# Out:
#       Item Category   Price  Quantity       Date
# 141  total    total   20.51       1.0 2021-03-01
# 162  total    total   71.67       1.0 2021-03-04
# 180  total    total   79.46       1.0 2021-03-06
# 237  total    total  206.99       1.0 2021-03-07
# 200  total    total   60.90       1.0 2021-03-10
# 135  total    total  137.93       1.0 2021-03-14
# 59   total    total   99.43       1.0 2021-03-17
# 31   total    total  154.12       1.0 2021-03-21
# 107  total    total   62.62       1.0 2021-03-25
# 90   total    total  123.53       1.0 2021-03-27
# 96   total    total   14.26       1.0 2021-03-27
# 274  total    total  106.94       1.0 2021-03-29

# %%
april.head(40)
# Out:
#                     Item      Category   Price  Quantity       Date
# 0                 coffee    dry pantry    3.99       1.0 2021-04-11
# 1        montauk seltzer        drinks   20.99       1.0 2021-04-11
# 2               loverboy        drinks   25.98       1.0 2021-04-11
# 3                  bread    dry pantry    5.50       1.0 2021-04-11
# 4        animal crackers        snacks    3.99       1.0 2021-04-11
# 5               crackers        snacks    4.99       1.0 2021-04-11
# 6                cookies        snacks    2.99       1.0 2021-04-11
# 7             beef broth        pantry    2.99       1.0 2021-04-11
# 8        animal crackers        snacks    9.98       1.0 2021-04-11
# 9        butter crackers        snacks    2.99       1.0 2021-04-11
# 10      cheddar crackers        snacks    4.69       1.0 2021-04-11
# 11                 panko    dry pantry    5.39       1.0 2021-04-11
# 12            beef chuck          meat   14.83       1.0 2021-04-11
# ...
